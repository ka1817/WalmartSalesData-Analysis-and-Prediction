# %% [markdown]
# # Walmart Sales Data Analysis and Predictions

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\saipr\\Downloads\\WalmartSalesData.csv.csv")

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df['Date'].unique()
# Out:
# array(['2019-01-05', '2019-03-08', '2019-03-03', '2019-01-27',
#        '2019-02-08', '2019-03-25', '2019-02-25', '2019-02-24',
#        '2019-01-10', '2019-02-20', '2019-02-06', '2019-03-09',
#        '2019-02-12', '2019-02-07', '2019-03-29', '2019-01-15',
#        '2019-03-11', '2019-01-01', '2019-01-21', '2019-03-05',
#        '2019-03-15', '2019-02-17', '2019-03-02', '2019-03-22',
#        '2019-03-10', '2019-01-25', '2019-01-28', '2019-01-07',
#        '2019-03-23', '2019-01-17', '2019-02-02', '2019-03-04',
#        '2019-03-16', '2019-02-27', '2019-02-10', '2019-03-19',
#        '2019-02-03', '2019-03-07', '2019-02-28', '2019-03-27',
#        '2019-01-20', '2019-03-12', '2019-02-15', '2019-03-06',
#        '2019-02-14', '2019-03-13', '2019-01-24', '2019-01-06',
#        '2019-02-11', '2019-01-22', '2019-01-13', '2019-01-09',
#        '2019-01-12', '2019-01-26', '2019-01-23', '2019-02-23',
#        '2019-01-02', '2019-02-09', '2019-03-26', '2019-03-01',
# ...

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df1=df.groupby(['Payment'],as_index=False)['Total'].sum().sort_values(by='Total')
df1
# Out:
#        Payment       Total
# 1  Credit card  100767.072
# 2      Ewallet  109993.107
# 0         Cash  112206.570

# %%
df2=df.groupby(['Product line'],as_index=False)['Product line'].value_counts()
df2
# Out:
#              Product line  count
# 0  Electronic accessories    170
# 1     Fashion accessories    178
# 2      Food and beverages    174
# 3       Health and beauty    152
# 4      Home and lifestyle    160
# 5       Sports and travel    166

# %%
df3=df.groupby(['City'],as_index=False)['Total'].sum()
df3
# Out:
#         City        Total
# 0   Mandalay  106197.6720
# 1  Naypyitaw  110568.7065
# 2     Yangon  106200.3705

# %%
#Extracting month from Date column
# Step 1: Convert the 'Date' column to datetime
df['Date'] = pd.to_datetime(df['Date'])
# Step 2: Extract the month from the 'Date' column
df['Month'] = df['Date'].dt.month_name()

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df4=df.groupby(['Month'],as_index=False)['Total'].sum().sort_values(by='Total',ascending=False)

# %%
df4
# Out:
#       Month       Total
# 1   January  116291.868
# 2     March  109455.507
# 0  February   97219.374

# %%
df5=df.groupby(['Month'],as_index=False)['gross income'].sum().sort_values(by='gross income',ascending=False)

# %%
df5
# Out:
#       Month  gross income
# 1   January      5537.708
# 2     March      5212.167
# 0  February      4629.494

# %%
df6=df.groupby(['Month'],as_index=False)['Tax 5%'].sum().sort_values(by='Tax 5%',ascending=False)

# %%
df6
# Out:
#       Month    Tax 5%
# 1   January  5537.708
# 2     March  5212.167
# 0  February  4629.494

# %%
df7=df.groupby(['Product line'],as_index=False)['Quantity'].sum().sort_values(by='Quantity',ascending=False)

# %%
df7
# Out:
#              Product line  Quantity
# 0  Electronic accessories       971
# 2      Food and beverages       952
# 5       Sports and travel       920
# 4      Home and lifestyle       911
# 1     Fashion accessories       902
# 3       Health and beauty       854

# %%
df8=df.groupby(['Gender','Product line'],as_index=False)['Total'].sum()

# %%
df8
# Out:
#     Gender            Product line       Total
# 0   Female  Electronic accessories  27102.0225
# 1   Female     Fashion accessories  30437.4000
# 2   Female      Food and beverages  33170.9175
# 3   Female       Health and beauty  18560.9865
# 4   Female      Home and lifestyle  30036.8775
# 5   Female       Sports and travel  28574.7210
# 6     Male  Electronic accessories  27235.5090
# 7     Male     Fashion accessories  23868.4950
# 8     Male      Food and beverages  22973.9265
# 9     Male       Health and beauty  30632.7525
# 10    Male      Home and lifestyle  23825.0355
# 11    Male       Sports and travel  26548.1055

# %%
df9=df.groupby(['Product line'],as_index=False)['Total'].sum()

# %%
df9
# Out:
#              Product line       Total
# 0  Electronic accessories  54337.5315
# 1     Fashion accessories  54305.8950
# 2      Food and beverages  56144.8440
# 3       Health and beauty  49193.7390
# 4      Home and lifestyle  53861.9130
# 5       Sports and travel  55122.8265

# %%
df10=df.groupby(['Product line'],as_index=False)['Rating'].mean()

# %%
df10
# Out:
#              Product line    Rating
# 0  Electronic accessories  6.924706
# 1     Fashion accessories  7.029213
# 2      Food and beverages  7.113218
# 3       Health and beauty  7.003289
# 4      Home and lifestyle  6.837500
# 5       Sports and travel  6.916265

# %%
df11=df.groupby(['Month'],as_index=False)['cogs'].sum().sort_values(by='cogs',ascending=False)

# %%
df11
# Out:
#       Month       cogs
# 1   January  110754.16
# 2     March  104243.34
# 0  February   92589.88

# %%
df12=df.groupby(['Gender'],as_index=False)['Total'].sum()

# %%
df12
# Out:
#    Gender       Total
# 0  Female  167882.925
# 1    Male  155083.824

# %%
df13=df.groupby(['Gender'],as_index=False)['Quantity'].sum()

# %%
df13
# Out:
#    Gender  Quantity
# 0  Female      2869
# 1    Male      2641

# %%
df14=df.groupby(['Product line'],as_index=False)['Unit price'].max().sort_values(by='Unit price',ascending=False)

# %%
df14
# Out:
#              Product line  Unit price
# 3       Health and beauty       99.96
# 5       Sports and travel       99.96
# 4      Home and lifestyle       99.92
# 1     Fashion accessories       99.89
# 2      Food and beverages       99.79
# 0  Electronic accessories       99.73

# %%
df15=df.groupby(['Customer type'],as_index=False)['Total'].sum()

# %%
df15
# Out:
#   Customer type       Total
# 0        Member  164223.444
# 1        Normal  158743.305

# %%
df16=df.groupby(['Product line'],as_index=False)['Rating'].max().sort_values(by='Rating',ascending=False)

# %%
df16
# Out:
#              Product line  Rating
# 0  Electronic accessories    10.0
# 3       Health and beauty    10.0
# 5       Sports and travel    10.0
# 1     Fashion accessories     9.9
# 2      Food and beverages     9.9
# 4      Home and lifestyle     9.9

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#        Time      Payment    cogs  gross margin percentage  gross income  \
# 0  13:08:00      Ewallet  522.83                 4.761905       26.1415
# ...

# %%
plt.figure(figsize=(6,4))
sns.barplot(x='City',y='Total',data=df3)
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.countplot(x='Gender',data=df,color='brown')
plt.show()

# %%
df17=df.groupby(['Branch'],as_index=False)['Total'].sum()
df17
# Out:
#   Branch        Total
# 0      A  106200.3705
# 1      B  106197.6720
# 2      C  110568.7065

# %%
plt.figure(figsize=(6,4))
sns.barplot(x='Branch',y='Total',data=df17,color='pink')
plt.show()

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#        Time      Payment    cogs  gross margin percentage  gross income  \
# 0  13:08:00      Ewallet  522.83                 4.761905       26.1415
# ...

# %%
sns.boxplot(x='Customer type',y='Total',data=df,color='grey')
# Out:
# <Axes: xlabel='Customer type', ylabel='Total'>

# %%
sns.violinplot(x='Month',y='Total',data=df,color='green')
# Out:
# <Axes: xlabel='Month', ylabel='Total'>

# %%
plt.figure(figsize=(12,5))
sns.violinplot(x="Product line", y="cogs", data=df,palette='rainbow')
sns.swarmplot(x="Product line", y="cogs", data=df,color='black',size=3)
# Out:
# C:\Users\saipr\AppData\Local\Temp\ipykernel_1216\1099069606.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="Product line", y="cogs", data=df,palette='rainbow')
# <Axes: xlabel='Product line', ylabel='cogs'>

# %%
sns.scatterplot(x='gross income',y='Rating',data=df)
# Out:
# <Axes: xlabel='gross income', ylabel='Rating'>

# %%
sns.swarmplot(x='Month',y='gross income',data=df,color='orange',size=3)
# Out:
# <Axes: xlabel='Month', ylabel='gross income'>

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#        Time      Payment    cogs  gross margin percentage  gross income  \
# 0  13:08:00      Ewallet  522.83                 4.761905       26.1415
# ...

# %%
#Extracting month from Date column
# Step 1: Convert the 'Date' column to datetime
df['Date'] = pd.to_datetime(df['Date'])
# Step 2: Extract the year from the 'Date' column
df['Year'] = df['Date'].dt.year

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# # Train Test Split

# %%
# Define X and y
X = df.drop(columns=['Invoice ID', 'Date', 'Time', 'Total','Branch'])
y = df['Total']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# # Training Model

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Model Evaluation

# %%
predictions=lm.predict(X_test)

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 6.478965512239181e-14
# MSE: 6.820764858321344e-27
# RMSE: 8.25879219881536e-14

# %% [markdown]
# # Example single input data

# %%
import pandas as pd
data = {
    'City': ['Yangon'],
    'Customer type': ['Normal'],
    'Gender': ['Female'],
    'Product line': ['Health and beauty'],
    'Unit price': [50.0],
    'Quantity': [10],
    'Tax 5%': [25.0],
    'Total': [525.0],  # This is what we want to predict
    'Date': ['2020-05-01'],
    'Time': ['12:00:00'],
    'Payment': ['Ewallet'],
    'cogs': [500.0],
    'gross margin percentage': [4.761905],
    'gross income': [25.0],
    'Rating': [8.0],
    'Month': ['May'],
    'Year': [2020]
}

# Convert to DataFrame
df_single = pd.DataFrame(data)

# Convert 'Date' column to datetime
df_single['Date'] = pd.to_datetime(df_single['Date'])
df_single['Month'] = df_single['Date'].dt.strftime('%B')
df_single['Year'] = df_single['Date'].dt.year

# Drop 'Date' and 'Time' columns if not used in model
df_single = df_single.drop(columns=['Date', 'Time'])

# %%
# Apply one-hot encoding to categorical columns
df_single_encoded = pd.get_dummies(df_single, columns=['City', 'Customer type', 'Gender', 'Product line', 'Payment', 'Month'], drop_first=True)

# %%
# Assuming `X` is the DataFrame used for training and has the columns in the correct order
# Align the columns in the single input DataFrame
for col in X.columns:
    if col not in df_single_encoded.columns:
        df_single_encoded[col] = 0

# Reorder columns to match the training data
df_single_encoded = df_single_encoded[X.columns]

# %%
# Use the trained model to predict the value
single_prediction = lm.predict(df_single_encoded)

# Output the predicted value
print(f'Predicted Total: {single_prediction[0]}')
# Out:
# Predicted Total: 525.0
